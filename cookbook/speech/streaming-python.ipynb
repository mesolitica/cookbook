# %%
import requests

with open('test.mp3', 'wb') as fopen:
    r = requests.get('https://huggingface.co/datasets/mesolitica/speech-test-set/resolve/main/test.mp3')
    fopen.write(r._content)

# %%
your_api_key = ''

# %%
import aiohttp
original_headers = {
    'Authorization': f'Bearer {your_api_key}',
}

audio_file = open('test.mp3', 'rb')
data_form = {
    'file': audio_file,
    'model': 'base',
    'language': 'ms',
    'stream': '1',
}
async with aiohttp.ClientSession() as session:
    async with session.post(
        'https://llm-router.nous.mesolitica.com/audio/transcriptions',
        headers=original_headers,
        data=data_form,
    ) as r:
        if r.status == 200:
            async for line in r.content:
                line = line.decode().strip()
                print(line)
# Out:
# data: {"token": "<|ms|>"}
#
# data: {"token": "<|0.02|>"}
#
# data: {"token": " Assembly"}
#
# data: {"token": " on"}
#
# data: {"token": " Ag"}
#
# data: {"token": "ing"}
#
# data: {"token": " di"}
#
# data: {"token": " Vienna"}
#
# data: {"token": ","}
#
# data: {"token": " Austria"}
#
# data: {"token": " yang"}
#
# data: {"token": " tel"}
#
# data: {"token": "ah"}
#
# data: {"token": " di"}
#
# data: {"token": "ad"}
#
# data: {"token": "akan"}
#
# data: {"token": " pada"}
#
# data: {"token": " tahun"}
#
# data: {"token": " 1982"}
#
# data: {"token": "<|6.44|>"}
#
# data: {"token": "<|6.44|>"}
#
# data: {"token": " dan"}
#
# data: {"token": " ber"}
#
# data: {"token": "as"}
#
# data: {"token": "ask"}
#
# data: {"token": "an"}
#
# data: {"token": " un"}
#
# data: {"token": "j"}
#
# data: {"token": "uran"}
#
# data: {"token": " ter"}
#
# data: {"token": "se"}
#
# data: {"token": "but"}
#
# data: {"token": " mak"}
#
# data: {"token": "a"}
#
# data: {"token": " Jab"}
#
# data: {"token": "atan"}
#
# data: {"token": " Per"}
#
# data: {"token": "ang"}
#
# data: {"token": "ka"}
#
# data: {"token": "an"}
#
# data: {"token": " Malaysia"}
#
# data: {"token": " meng"}
#
# data: {"token": "ang"}
#
# data: {"token": "g"}
#
# data: {"token": "arkan"}
#
# data: {"token": "<|11.6|>"}
#
# data: {"token": "<|11.6|>"}
#
# data: {"token": " men"}
#
# data: {"token": "j"}
#
# data: {"token": "el"}
#
# data: {"token": "ang"}
#
# data: {"token": " tahun"}
#
# data: {"token": " 20"}
#
# data: {"token": "35"}
#
# data: {"token": " se"}
#
# data: {"token": "j"}
#
# data: {"token": "um"}
#
# data: {"token": "lah"}
#
# data: {"token": " 15"}
#
# data: {"token": "%"}
#
# data: {"token": " pend"}
#
# data: {"token": "ud"}
#
# data: {"token": "uk"}
#
# data: {"token": " kita"}
#
# data: {"token": " adalah"}
#
# data: {"token": " dar"}
#
# data: {"token": "ip"}
#
# data: {"token": "ada"}
#
# data: {"token": " kal"}
#
# data: {"token": "angan"}
#
# data: {"token": " war"}
#
# data: {"token": "ga"}
#
# data: {"token": " em"}
#
# data: {"token": "as"}
#
# data: {"token": "<|18.72|>"}
#
# data: {"token": "<|18.72|>"}
#
# data: {"token": " untuk"}
#
# data: {"token": " mak"}
#
# data: {"token": "l"}
#
# data: {"token": "uman"}
#
# data: {"token": " T"}
#
# data: {"token": "uan"}
#
# data: {"token": " Yang"}
#
# data: {"token": " Put"}
#
# data: {"token": "u"}
#
# data: {"token": "wa"}
#
# data: {"token": " dan"}
#
# data: {"token": " juga"}
#
# data: {"token": " Al"}
#
# data: {"token": "iam"}
#
# data: {"token": " Boh"}
#
# data: {"token": "mat"}
#
# data: {"token": "<|22.1|>"}
#
# data: {"token": "<|22.1|>"}
#
# data: {"token": " pem"}
#
# data: {"token": "bang"}
#
# data: {"token": "un"}
#
# data: {"token": "an"}
#
# data: {"token": " sistem"}
#
# data: {"token": " p"}
#
# data: {"token": "enda"}
#
# data: {"token": "ft"}
#
# data: {"token": "aran"}
#
# data: {"token": " war"}
#
# data: {"token": "ga"}
#
# data: {"token": " em"}
#
# data: {"token": "as"}
#
# data: {"token": " ata"}
#
# data: {"token": "upun"}
#
# data: {"token": " kita"}
#
# data: {"token": " se"}
#
# data: {"token": "but"}
#
# data: {"token": "kan"}
#
# data: {"token": " I"}
#
# data: {"token": "W"}
#
# data: {"token": "EN"}
#
# data: {"token": "<|25.38|>"}
